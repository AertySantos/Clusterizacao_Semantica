# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("analise.csv")
df.head()
# Out:
#   LINK  ID da resposta        Data de envio  Última página Idioma inicial  \
# 0  INT             568  2021-06-20 15:00:50              7          pt-BR
# 1  EXT             167  2021-05-21 22:10:05              7          pt-BR
# 2  INT             489  2021-06-20 11:19:30              7          pt-BR
# 3  INT             536  2021-06-20 13:19:52              7          pt-BR
# 4  INT             486  2021-06-20 11:07:55              7          pt-BR
#
#       Semente     Código de Acesso       Data de início  Data da última ação  \
# 0  1767601499      uB3EaV9IXANbGvm  2021-06-20 14:55:17  2021-06-20 15:00:49
# 1  1839169195  2021-05-21 21:59:31  2021-05-21 22:10:05                  NaN
# 2   258990084      BgKQgz43AnBGl68  2021-06-20 11:13:00  2021-06-20 11:19:30
# 3  1424695604      wDN4DUIbrCgBWaG  2021-06-20 13:05:17  2021-06-20 13:19:52
# 4   667378996      8vgAKmEjIZKMDvf  2021-06-20 11:03:18  2021-06-20 11:07:55
#
# ...

# %%
filtered_df = df[df.columns[-1]]
filtered_df.value_counts()
# Out:
# 0
# 1    103
# 4     73
# 0     51
# 2     47
# 3     41
# Name: count, dtype: int64

# %%
cluster_0 = df[df[df.columns[-1]] == 0]
cluster_0.describe()
# Out:
#        ID da resposta  Última página       Semente      IDADE       CON1  \
# count       51.000000           51.0  5.100000e+01  51.000000  51.000000
# mean       465.627451            7.0  1.043480e+09  32.686275   4.764706
# std        343.149353            0.0  5.889737e+08  10.797204   1.530859
# min          4.000000            7.0  1.209779e+07  18.000000   1.000000
# 25%        151.500000            7.0  4.789983e+08  23.500000   4.000000
# 50%        452.000000            7.0  1.101038e+09  32.000000   5.000000
# 75%        747.000000            7.0  1.549799e+09  39.000000   6.000000
# max       1057.000000            7.0  2.069488e+09  57.000000   7.000000
#
#             CON2       CON3       CON4       CON5       CON6  ...       ENV2  \
# count  51.000000  51.000000  51.000000  51.000000  51.000000  ...  51.000000
# mean    5.666667   5.568627   4.098039   4.803922   5.294118  ...   5.294118
# std     1.143095   1.220736   1.824882   1.637310   1.269553  ...   1.640660
# ...

# %%
cluster_1 = df[df[df.columns[-1]] == 1]
cluster_1.describe()
# Out:
#        ID da resposta  Última página       Semente       IDADE        CON1  \
# count      103.000000          103.0  1.030000e+02  103.000000  103.000000
# mean       429.844660            7.0  1.076928e+09   30.844660    4.893204
# std        332.056272            0.0  6.173339e+08   10.604991    1.507580
# min          6.000000            7.0  1.360760e+07   17.000000    1.000000
# 25%        134.500000            7.0  5.943373e+08   21.000000    4.000000
# 50%        317.000000            7.0  9.911760e+08   30.000000    5.000000
# 75%        726.000000            7.0  1.585006e+09   36.500000    6.000000
# max       1058.000000            7.0  2.120632e+09   60.000000    7.000000
#
#              CON2        CON3        CON4        CON5        CON6  ...  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000  ...
# mean     5.864078    5.766990    3.436893    5.097087    5.165049  ...
# std      1.213071    1.401707    2.056410    1.648021    1.528148  ...
# ...

# %%
cluster_2 = df[df[df.columns[-1]] == 2]
cluster_2.describe()
# Out:
#        ID da resposta  Última página       Semente      IDADE       CON1  \
# count       47.000000           47.0  4.700000e+01  47.000000  47.000000
# mean       535.000000            7.0  1.186436e+09  33.255319   3.085106
# std        306.845167            0.0  7.044380e+08  11.533445   1.442067
# min          7.000000            7.0  1.605851e+07  18.000000   1.000000
# 25%        262.500000            7.0  5.720390e+08  22.500000   2.000000
# 50%        569.000000            7.0  1.257488e+09  33.000000   3.000000
# 75%        783.000000            7.0  1.829229e+09  41.500000   4.000000
# max       1012.000000            7.0  2.142669e+09  63.000000   6.000000
#
#             CON2       CON3       CON4       CON5       CON6  ...       ENV2  \
# count  47.000000  47.000000  47.000000  47.000000  47.000000  ...  47.000000
# mean    3.957447   3.638298   2.510638   3.234043   3.638298  ...   4.382979
# std     1.531658   1.647469   1.396772   1.386468   1.389800  ...   1.688235
# ...

# %%
cluster_3 = df[df[df.columns[-1]] == 3]
cluster_3.describe()
# Out:
#        ID da resposta  Última página       Semente      IDADE       CON1  \
# count       41.000000           41.0  4.100000e+01  41.000000  41.000000
# mean       448.926829            7.0  9.850604e+08  31.219512   3.317073
# std        339.296065            0.0  6.730617e+08   9.480275   1.664918
# min          4.000000            7.0  2.357241e+07  17.000000   1.000000
# 25%        113.000000            7.0  3.782072e+08  24.000000   2.000000
# 50%        466.000000            7.0  8.631989e+08  31.000000   3.000000
# 75%        696.000000            7.0  1.715792e+09  38.000000   4.000000
# max       1056.000000            7.0  2.097483e+09  55.000000   7.000000
#
#             CON2       CON3       CON4       CON5       CON6  ...       ENV2  \
# count  41.000000  41.000000  41.000000  41.000000  41.000000  ...  41.000000
# mean    5.146341   4.268293   1.902439   3.512195   3.609756  ...   6.390244
# std     1.295395   1.923855   1.200102   1.790558   1.715780  ...   0.918642
# ...

# %%
cluster_4 = df[df[df.columns[-1]] == 4]
cluster_4.describe()
# Out:
#        ID da resposta  Última página       Semente          IDADE       CON1  \
# count       73.000000           73.0  7.300000e+01      73.000000  73.000000
# mean       397.821918            7.0  1.001122e+09    8196.452055   2.287671
# std        319.070148            0.0  5.906008e+08   69747.853569   1.358916
# min          8.000000            7.0  4.701151e+07      17.000000   1.000000
# 25%        136.000000            7.0  4.747411e+08      27.000000   1.000000
# 50%        299.000000            7.0  1.049811e+09      34.000000   2.000000
# 75%        654.000000            7.0  1.424992e+09      40.000000   3.000000
# max       1054.000000            7.0  2.129011e+09  595959.000000   7.000000
#
#             CON2       CON3       CON4       CON5       CON6  ...       ENV2  \
# count  73.000000  73.000000  73.000000  73.000000  73.000000  ...  73.000000
# mean    4.068493   3.136986   1.575342   2.246575   2.753425  ...   4.849315
# ...
